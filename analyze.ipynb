# %% [markdown]
# <a href="https://colab.research.google.com/github/sdancyger/module1-codexes-claims-analysis/blob/main/analyze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install pandas

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')

# %%
df
# Out:
#       BENE_ID|CLM_ID|NCH_NEAR_LINE_REC_IDENT_CD|NCH_CLM_TYPE_CD|CLM_FROM_DT|CLM_THRU_DT|NCH_WKLY_PROC_DT|FI_CLM_PROC_DT|CLAIM_QUERY_CODE|PRVDR_NUM|CLM_FAC_TYPE_CD|CLM_SRVC_CLSFCTN_TYPE_CD|CLM_FREQ_CD|FI_NUM|CLM_MDCR_NON_PMT_RSN_CD|CLM_PMT_AMT|NCH_PRMRY_PYR_CLM_PD_AMT|NCH_PRMRY_PYR_CD|FI_CLM_ACTN_CD|PRVDR_STATE_CD|ORG_NPI_NUM|AT_PHYSN_UPIN|AT_PHYSN_NPI|OP_PHYSN_UPIN|OP_PHYSN_NPI|OT_PHYSN_UPIN|OT_PHYSN_NPI|CLM_MCO_PD_SW|PTNT_DSCHRG_STUS_CD|CLM_PPS_IND_CD|CLM_TOT_CHRG_AMT|CLM_ADMSN_DT|CLM_IP_ADMSN_TYPE_CD|CLM_SRC_IP_ADMSN_CD|NCH_PTNT_STATUS_IND_CD|CLM_PASS_THRU_PER_DIEM_AMT|NCH_BENE_IP_DDCTBL_AMT|NCH_BENE_PTA_COINSRNC_LBLTY_AM|NCH_BENE_BLOOD_DDCTBL_LBLTY_AM|NCH_PROFNL_CMPNT_CHRG_AMT|NCH_IP_NCVRD_CHRG_AMT|NCH_IP_TOT_DDCTN_AMT|CLM_TOT_PPS_CPTL_AMT|CLM_PPS_CPTL_FSP_AMT|CLM_PPS_CPTL_OUTLIER_AMT|CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT|CLM_PPS_CPTL_IME_AMT|CLM_PPS_CPTL_EXCPTN_AMT|CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT|CLM_PPS_CPTL_DRG_WT_NUM|CLM_UTLZTN_DAY_CNT|BENE_TOT_COINSRNC_DAYS_CNT|BENE_LRD_USED_CNT|CLM_
# ...

# %%
df = pd.read_csv(
    'https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
    sep= '|')
# Out:
# <ipython-input-48-042e68e7af73>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
#df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')

# %%
df = pd.read_csv(
    'https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
    sep= '|')
# Out:
# <ipython-input-51-042e68e7af73>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
#### random sample
df.sample(20)
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 35557 -10000010274102 -10000930906324                          V
# 17688 -10000010263682 -10000930446504                          V
# 55702 -10000010286176 -10000931409532                          V
# 15449 -10000010262553 -10000930392306                          V
# 46299 -10000010280051 -10000931176891                          V
# 3009  -10000010255882 -10000930089985                          V
# 5296  -10000010257456 -10000930149599                          V
# 44135 -10000010278318 -10000931112728                          V
# 17342 -10000010263389 -10000930433046                          V
# 46490 -10000010280274 -10000931183660                          V
# 10930 -10000010259769 -10000930270596                          V
# 27953 -10000010270040 -10000930716149                          V
# 12273 -10000010260287 -10000930294628                          V
# ...

# %%
#### column

# %%
### Explore data

for column in df.columns:
  print(column)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
### Explore

# df.PRNCPAL_DGNS_CD
# df['PRNCPAL_DGNS_CD']

df.PRNCPAL_DGNS_CD
# Out:
# 0         S134XX
# 1          Z3480
# 2         T7432X
# 3         S8290X
# 4         S8290X
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065     S93409
# Name: PRNCPAL_DGNS_CD, Length: 58066, dtype: object

# %% [markdown]
# Code check: Z3480= Encounter for supervision of other normal pregnancy, unspecified trimester

# %%
### get unique count of claim id
df.CLM_ID.unique()
# Out:
# array([-10000930037831, -10000930038030, -10000930038031, ...,
#        -10000931485969, -10000931485971, -10000931486024])

# %%
count = df.CLM_ID.unique()
len(count)
# Out:
# 20867

# %%
### See a list of the most frequent ICD codes and the least frequent ICD codes ###
df.PRNCPAL_DGNS_CD.value_counts()
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %% [markdown]
# Z733  = Stress, not elsewhere classified
# Z608 = Other problems related to social environment
# T7432X = Child psychological abuse, confirmed, initial encounter
# Z604 = Social exclusion and rejection
# Z7682 = Awaiting organ transplant status

# %%
icd_primary_counts = df.PRNCPAL_DGNS_CD.value_counts()
icd_primary_counts
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %%
type(icd_primary_counts)
# Out:
# pandas.core.series.Series

# %%
### Says if it is an integer (but this is incorrect data type/autosuggest)
df.dtypes
# Out:
# BENE_ID                          int64
# CLM_ID                           int64
# NCH_NEAR_LINE_REC_IDENT_CD      object
# NCH_CLM_TYPE_CD                  int64
# CLM_FROM_DT                     object
#                                 ...
# CLM_UNCOMPD_CARE_PMT_AMT       float64
# CLM_LINE_NUM                     int64
# REV_CNTR                         int64
# HCPCS_CD                        object
# REV_CNTR_DDCTBL_COINSRNC_CD    float64
# Length: 197, dtype: object

# %%
### Explore data

for column in df.columns:
  print(column)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
### Explore

# df.PRNCPAL_DGNS_CD

df.PRNCPAL_DGNS_CD
# Out:
# 0         S134XX
# 1          Z3480
# 2         T7432X
# 3         S8290X
# 4         S8290X
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065     S93409
# Name: PRNCPAL_DGNS_CD, Length: 58066, dtype: object

# %% [markdown]
# S134XX = sprain of ligaments in cervical spine
# Z3480 = Encounter for supervision of other normal pregnancy, unspecified trimester
# T50901A = Poisoning by unspecified drugs, medicaments and biological substances, accidental (unintentional), initial encounter
# S93409 = Sprain of unspecified ligament of unspecified ankle

# %%
#### Random sample

df.PRNCPAL_DGNS_CD
df.sample(5)
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 28826 -10000010270707 -10000930740928                          V
# 13161 -10000010260977 -10000930318169                          V
# 9367  -10000010259214 -10000930240763                          V
# 4453  -10000010256736 -10000930124814                          V
# 49051 -10000010282378 -10000931259804                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 28826               60  18-Oct-2020  29-Oct-2020      30-Oct-2020
# 13161               60  10-May-2018  10-May-2018      11-May-2018
# 9367                60  21-Mar-2018  21-Mar-2018      23-Mar-2018
# 4453                60  13-Oct-2016  13-Oct-2016      14-Oct-2016
# 49051               60  19-Feb-2020  19-Feb-2020      21-Feb-2020
#
#        FI_CLM_PROC_DT  CLAIM_QUERY_CODE PRVDR_NUM  ...  PRCDR_DT24  \
# 28826             NaN                 3    33T014  ...         NaN
# ...

# %%
df.columns
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
df.CLM_LINE_NUM
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
#         ..
# 58061    1
# 58062    1
# 58063    1
# 58064    1
# 58065    1
# Name: CLM_LINE_NUM, Length: 58066, dtype: int64

# %%
df.CLM_LINE_NUM.describe()
# Out:
# count    58066.000000
# mean         3.341370
# std          3.050711
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max         46.000000
# Name: CLM_LINE_NUM, dtype: float64

# %%
df.PRVDR_NUM
# Out:
# 0        011500
# 1        017129
# 2        010052
# 3        015455
# 4        015455
#           ...
# 58061    050243
# 58062    056428
# 58063    056428
# 58064    050243
# 58065    555851
# Name: PRVDR_NUM, Length: 58066, dtype: object

# %%
df.PRVDR_NUM.describe()
# Out:
# count      55225
# unique      4876
# top       491581
# freq        1093
# Name: PRVDR_NUM, dtype: object
